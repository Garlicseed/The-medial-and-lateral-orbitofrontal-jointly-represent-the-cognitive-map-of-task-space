# %%
import matplotlib.pyplot as plt
categories = np.array(['(Fy)Fo', '(Fo)Fy', '(Hy)Ho', '(Ho)Hy', '(Fy)Fy', '(Fo)Fo', '(Hy)Hy', '(Ho)Ho', '(Fy)Hy', '(Fy)Ho', '(Fo)Hy', '(Fo)Ho', '(Hy)Fy', '(Hy)Fo', '(Ho)Fy', '(Ho)Fo'])
mm = 1 / 25.4
from matplotlib import rcParams
rcParams['font.family'] = 'monospace'
aa_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/aa_rdm.npy')
bb_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/bb_rdm.npy')
cc_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/cc_rdm.npy')
dd_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/dd_rdm.npy')
rdms = ['aa_rdm','bb_rdm','cc_rdm']
GREY_LIGHT = "#b4aea9"
GREY_DARK = "#747473"
def plot_rdm(ax, rdm, categories):
    im = ax.imshow(rdm, cmap='GnBu', vmin=0, alpha=0.45, origin='upper')
    ax.set_xticks(np.arange(len(categories)))
    ax.set_yticks(np.arange(len(categories)))
    ax.set_xticklabels(categories, rotation=90, fontsize=2.0)
    ax.set_yticklabels(categories, fontsize=2.0)

    labels = ax.get_xticklabels()
    labels1 = ax.get_yticklabels()

    # 设置x轴标签的颜色
    for label in labels:
        text = label.get_text()
        if text in ['(Fy)Fo', '(Fo)Fy', '(Hy)Ho', '(Ho)Hy']:
            label.set_color('#1B9E77')
        elif text in ['(Fy)Fy', '(Fo)Fo', '(Hy)Hy', '(Ho)Ho']:
            label.set_color('#D95F02')
        else:
            label.set_color('#7570B3')

    # 设置y轴标签的颜色
    for label1 in labels1:
        text = label1.get_text()
        if text in ['(Fy)Fo', '(Fo)Fy', '(Hy)Ho', '(Ho)Hy']:
            label1.set_color('#1B9E77')
        elif text in ['(Fy)Fy', '(Fo)Fo', '(Hy)Hy', '(Ho)Ho']:
            label1.set_color('#D95F02')
        else:
            label1.set_color('#7570B3')
    ax.tick_params(axis='both', which='major', length=1.2, width=0.4,color = GREY_DARK)
    ax.tick_params(axis='both', which='major', pad=1.0)
    ax.spines['top'].set_linewidth(0.4)
    ax.spines['top'].set_color(GREY_DARK)
    ax.spines['bottom'].set_linewidth(0.4)
    ax.spines['bottom'].set_color(GREY_DARK)
    ax.spines['left'].set_linewidth(0.4)
    ax.spines['left'].set_color(GREY_DARK)
    ax.spines['right'].set_linewidth(0.4)
    ax.spines['right'].set_color(GREY_DARK)

    plt.tight_layout()
    return im
rdm_files = ['aa_rdm','bb_rdm', 'cc_rdm', 'dd_rdm']
titles = ['Enter_non-Enter', 'Exit_non-Exit', 'Control1', 'Control2']
f, axs = plt.subplots(1, len(rdm_files), figsize=(100 * mm, 50 * mm), dpi=300)
for i, rdm_file in enumerate(rdm_files):
    rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/{rdm_file}.npy')
    im = plot_rdm(axs[i], rdm, categories)
    axs[i].set_title(titles[i],fontsize=4,y=0.94, fontdict={'family': 'DejaVu Sans'})
cbar_ax = f.add_axes([0.98, 0.345, 0.02, 0.31])
cbar_ax.set_aspect(12)
cbar = f.colorbar(im, cax=cbar_ax)
cbar.outline.set_linewidth(0.35)
cbar.set_ticks([0, 1])
cbar.ax.tick_params(labelsize=4, length=1,pad = 0.5,width=0.3)    
plt.savefig(f"/media/garlicseed/data/final/RSA/theory_rdm/Figures/theory_rdm.svg", dpi=300, format="svg", bbox_inches='tight')
plt.savefig(f"/media/garlicseed/data/final/RSA/theory_rdm/Figures/theory_rdm.png", dpi=300, format="png", bbox_inches='tight')
#plt.tight_layout()    
plt.show()

# %%
#
import matplotlib.pyplot as plt
categories = np.array(['(Fy)Fo', '(Fo)Fy', '(Hy)Ho', '(Ho)Hy', '(Fy)Fy', '(Fo)Fo', '(Hy)Hy', '(Ho)Ho', '(Fy)Hy', '(Fy)Ho', '(Fo)Hy', '(Fo)Ho', '(Hy)Fy', '(Hy)Fo', '(Ho)Fy', '(Ho)Fo'])
mm = 1 / 25.4
from matplotlib import rcParams
rcParams['font.family'] = 'monospace'
aa_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/aa_rdm.npy')
bb_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/bb_rdm.npy')
cc_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/cc_rdm.npy')
dd_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/dd_rdm.npy')
rdms = ['aa_rdm','bb_rdm','cc_rdm']
GREY_LIGHT = "#b4aea9"
GREY_DARK = "#747473"
def plot_rdm(ax, rdm, categories):
    im = ax.imshow(rdm, cmap='GnBu', vmin=0, alpha=0.45, origin='upper')
    ax.set_xticks(np.arange(len(categories)))
    ax.set_yticks(np.arange(len(categories)))
    ax.set_xticklabels(categories, rotation=90, fontsize=2.0)
    ax.set_yticklabels(categories, fontsize=2.0)

    labels = ax.get_xticklabels()
    labels1 = ax.get_yticklabels()

    # 设置x轴标签的颜色
    for label in labels:
        text = label.get_text()
        if text in ['(Fy)Fo', '(Fo)Fy', '(Hy)Ho', '(Ho)Hy']:
            label.set_color('#1B9E77')
        elif text in ['(Fy)Fy', '(Fo)Fo', '(Hy)Hy', '(Ho)Ho']:
            label.set_color('#D95F02')
        else:
            label.set_color('#7570B3')

    # 设置y轴标签的颜色
    for label1 in labels1:
        text = label1.get_text()
        if text in ['(Fy)Fo', '(Fo)Fy', '(Hy)Ho', '(Ho)Hy']:
            label1.set_color('#1B9E77')
        elif text in ['(Fy)Fy', '(Fo)Fo', '(Hy)Hy', '(Ho)Ho']:
            label1.set_color('#D95F02')
        else:
            label1.set_color('#7570B3')
    ax.tick_params(axis='both', which='major', length=1.2, width=0.4,color = GREY_DARK)
    ax.tick_params(axis='both', which='major', pad=1.0)
    ax.spines['top'].set_linewidth(0.4)
    ax.spines['top'].set_color(GREY_DARK)
    ax.spines['bottom'].set_linewidth(0.4)
    ax.spines['bottom'].set_color(GREY_DARK)
    ax.spines['left'].set_linewidth(0.4)
    ax.spines['left'].set_color(GREY_DARK)
    ax.spines['right'].set_linewidth(0.4)
    ax.spines['right'].set_color(GREY_DARK)

    plt.tight_layout()
    return im
rdm_files = ['aa_rdm.npy','bb_rdm.npy', 'cc_rdm.npy', 'ee_rdm.npy']
f, axs = plt.subplots(1, len(rdm_files), figsize=(100 * mm, 50 * mm), dpi=300)
for i, rdm_file in enumerate(rdm_files):
    rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/{rdm_file}')
    im = plot_rdm(axs[i], rdm, categories)

cbar_ax = f.add_axes([0.98, 0.345, 0.02, 0.31])
cbar_ax.set_aspect(12)
cbar = f.colorbar(im, cax=cbar_ax)
cbar.outline.set_linewidth(0.35)
cbar.set_ticks([0, 1])
cbar.ax.tick_params(labelsize=3.5, length=1.5,pad = 0.5,width=0.3)    
#plt.savefig(f"/home/garlicseed/Mount/final/RSA/theory_rdm/Figures/theory_rdm.svg", dpi=300, format="svg", bbox_inches='tight')
#plt.savefig(f"/home/garlicseed/Mount/final/RSA/theory_rdm/Figures/theory_rdm.png", dpi=300, format="png", bbox_inches='tight')
plt.tight_layout()    
plt.show()
# Out:
# /tmp/ipykernel_8849/3345549481.py:70: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
categories = np.array(['(Fy)Fo', '(Fo)Fy', '(Hy)Ho', '(Ho)Hy', '(Fy)Fy', '(Fo)Fo', '(Hy)Hy', '(Ho)Ho', '(Fy)Hy', '(Fy)Ho', '(Fo)Hy', '(Fo)Ho', '(Hy)Fy', '(Hy)Fo', '(Ho)Fy', '(Ho)Fo'])
mm = 1 / 25.4
from matplotlib import rcParams
rcParams['font.family'] = 'monospace'
aa_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/aa_rdm.npy')
bb_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/bb_rdm.npy')
cc_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/cc_rdm.npy')
dd_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/dd_rdm.npy')
rdms = ['aa_rdm','bb_rdm','cc_rdm']
GREY_LIGHT = "#b4aea9"
GREY_DARK = "#747473"
def plot_rdm(ax, rdm, categories):
    im = ax.imshow(rdm, cmap='GnBu', vmin=0, alpha=0.45, origin='upper')
    ax.set_xticks(np.arange(len(categories)))
    ax.set_yticks(np.arange(len(categories)))
    ax.set_xticklabels(categories, rotation=90, fontsize=4.0)
    ax.set_yticklabels(categories, fontsize=4.0)

    labels = ax.get_xticklabels()
    labels1 = ax.get_yticklabels()

    # 设置x轴标签的颜色
    for label in labels:
        text = label.get_text()
        if text in ['(Fy)Fo', '(Fo)Fy', '(Hy)Ho', '(Ho)Hy']:
            label.set_color('#1B9E77')
        elif text in ['(Fy)Fy', '(Fo)Fo', '(Hy)Hy', '(Ho)Ho']:
            label.set_color('#D95F02')
        else:
            label.set_color('#7570B3')

    # 设置y轴标签的颜色
    for label1 in labels1:
        text = label1.get_text()
        if text in ['(Fy)Fo', '(Fo)Fy', '(Hy)Ho', '(Ho)Hy']:
            label1.set_color('#1B9E77')
        elif text in ['(Fy)Fy', '(Fo)Fo', '(Hy)Hy', '(Ho)Ho']:
            label1.set_color('#D95F02')
        else:
            label1.set_color('#7570B3')
    ax.tick_params(axis='both', which='major', length=1.6, width=0.7,color = GREY_DARK)
    ax.tick_params(axis='both', which='major', pad=1.0)
    ax.spines['top'].set_linewidth(0.7)
    ax.spines['top'].set_color(GREY_DARK)
    ax.spines['bottom'].set_linewidth(0.7)
    ax.spines['bottom'].set_color(GREY_DARK)
    ax.spines['left'].set_linewidth(0.7)
    ax.spines['left'].set_color(GREY_DARK)
    ax.spines['right'].set_linewidth(0.7)
    ax.spines['right'].set_color(GREY_DARK)

    plt.tight_layout()
    return im
rdm_files = ['ee_rdm.npy']
f, axs = plt.subplots(1, len(rdm_files), figsize=(100 * mm, 50 * mm), dpi=300)
for i, rdm_file in enumerate(rdm_files):
    rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/{rdm_file}')
    im = plot_rdm(axs, rdm, categories)
cbar_ax = f.add_axes([0.73, 0.20, 0.025, 0.72])
cbar_ax.set_aspect(12)
cbar = f.colorbar(im, cax=cbar_ax)
cbar.outline.set_linewidth(0.55)
cbar.set_ticks([0, 1])
cbar.ax.tick_params(labelsize=3.5, length=1.5,pad = 0.5,width=0.50)
plt.savefig(f"/home/garlicseed/Mount/final/RSA/theory_rdm/Figures/ee_theory_rdm.svg", dpi=300, format="svg", bbox_inches='tight')
plt.savefig(f"/home/garlicseed/Mount/final/RSA/theory_rdm/Figures/ee_theory_rdm.png", dpi=300, format="png", bbox_inches='tight')

# %%
import numpy as np
dd_rdm = np.load(f'/home/garlicseed/Mount/final/RSA/rdm_matrix/ee_rdm.npy')
import matplotlib.pyplot as plt
plt.imshow(dd_rdm)
plt.xlabel("States", fontsize=15)
plt.ylabel("States", fontsize=15)
cbar = plt.colorbar()
cbar.ax.set_ylabel('Dissimilarity', fontsize=15)
plt.show()

# %%
# Out:
# /tmp/ipykernel_8849/3554751784.py:69: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
